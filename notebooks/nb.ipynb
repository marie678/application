# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

train = pd.read_csv("../train.csv")
test = pd.read_csv("../test.csv")
X_train, y_train = train.drop("Survived", axis="columns"), train["Survived"]
X_test, y_test = test.drop("Survived", axis="columns"), train["Survived"]

MAX_DEPTH = None
MAX_FEATURES = "sqrt"
n_trees=20

numeric_features = ["Age", "Fare"]
categorical_features = ["Embarked", "Sex"]

# Variables numériques
numeric_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", MinMaxScaler()),
    ]
)

# Variables catégorielles
categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", OneHotEncoder()),
    ]
)

# Preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ("Preprocessing numerical", numeric_transformer, numeric_features),
        (
            "Preprocessing categorical",
            categorical_transformer,
            categorical_features,
        ),
    ]
)

# Pipeline
pipe = Pipeline(
    [
        ("preprocessor", preprocessor),
        ("classifier", RandomForestClassifier(
            n_estimators=n_trees,
            max_depth=MAX_DEPTH,
            max_features=MAX_FEATURES
        )),
    ]
)

pipe

pipe.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 62
#      49 pipe = Pipeline(
#      50     [
#      51         ("preprocessor", preprocessor),
#    (...)
#      57     ]
#      58 )
#      60 pipe
# ---> 62 pipe.fit(X_train, y_train)
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/pipeline.py:662, in Pipeline.fit(self, X, y, **params)
#     656     if self._final_estimator != "passthrough":
#     657         last_step_params = self._get_metadata_for_step(
#     658             step_idx=len(self) - 1,
#     659             step_params=routed_params[self.steps[-1][0]],
#     660             all_params=params,
#     661         )
# --> 662         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     664 return self
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:360, in BaseForest.fit(self, X, y, sample_weight)
#     357 if issparse(y):
#     358     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 360 X, y = validate_data(
#     361     self,
#     362     X,
#     363     y,
#     364     multi_output=True,
#     365     accept_sparse="csc",
#     366     dtype=DTYPE,
#     367     ensure_all_finite=False,
#     368 )
#     369 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     370 # will raise an error if the underlying tree base estimator can't handle missing
#     371 # values. Only the criterion is required to determine if the tree supports
#     372 # missing values.
#     373 estimator = type(self.estimator)(criterion=self.criterion)
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/utils/validation.py:2961, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959         y = check_array(y, input_name="y", **check_y_params)
#    2960     else:
# -> 2961         X, y = check_X_y(X, y, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/utils/validation.py:1387, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1368 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    (...)
#    1384     input_name="X",
#    1385 )
# -> 1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1389 check_consistent_length(X, y)
#    1391 return X, y
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/utils/validation.py:1397, in _check_y(y, multi_output, y_numeric, estimator)
#    1395 """Isolated part of check_X_y dedicated to y validation"""
#    1396 if multi_output:
# -> 1397     y = check_array(
#    1398         y,
#    1399         accept_sparse="csr",
#    1400         ensure_all_finite=True,
#    1401         ensure_2d=False,
#    1402         dtype=None,
#    1403         input_name="y",
#    1404         estimator=estimator,
#    1405     )
#    1406 else:
#    1407     estimator_name = _check_estimator_name(estimator)
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/utils/validation.py:1107, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1101     raise ValueError(
#    1102         "Found array with dim %d. %s expected <= 2."
#    1103         % (array.ndim, estimator_name)
#    1104     )
#    1106 if ensure_all_finite:
# -> 1107     _assert_all_finite(
#    1108         array,
#    1109         input_name=input_name,
#    1110         estimator_name=estimator_name,
#    1111         allow_nan=ensure_all_finite == "allow-nan",
#    1112     )
#    1114 if copy:
#    1115     if _is_numpy_namespace(xp):
#    1116         # only make a copy if `array` and `array_orig` may share memory`
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/utils/validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input y contains NaN.

# %%
pipe
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Preprocessing numerical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Age', 'Fare']),
#                                                  ('Preprocessing categorical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder())]),
#                                                   ['Embarked', 'Sex'])])),
#                 ('classifier', RandomForestClassifier(n_estimators=20))])

# %%
pipe[0]
# Out:
# ColumnTransformer(transformers=[('Preprocessing numerical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', MinMaxScaler())]),
#                                  ['Age', 'Fare']),
#                                 ('Preprocessing categorical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot', OneHotEncoder())]),
#                                  ['Embarked', 'Sex'])])

# %%
pipe[:-1]
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Preprocessing numerical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Age', 'Fare']),
#                                                  ('Preprocessing categorical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder())]),
#                                                   ['Embarked', 'Sex'])]))])

# %%
pipe['preprocessor']
# Out:
# ColumnTransformer(transformers=[('Preprocessing numerical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', MinMaxScaler())]),
#                                  ['Age', 'Fare']),
#                                 ('Preprocessing categorical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot', OneHotEncoder())]),
#                                  ['Embarked', 'Sex'])])

# %%
pipe['preprocessor']['Preprocessing numerical']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/conda/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:1251, in ColumnTransformer.__getitem__(self, key)
#    1250 try:
# -> 1251     return self.named_transformers_[key]
#    1252 except AttributeError as e:
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:598, in ColumnTransformer.named_transformers_(self)
#     597 # Use Bunch object to improve autocomplete
# --> 598 return Bunch(**{name: trans for name, trans, _ in self.transformers_})
#
# AttributeError: 'ColumnTransformer' object has no attribute 'transformers_'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 pipe['preprocessor']['Preprocessing numerical']
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:1253, in ColumnTransformer.__getitem__(self, key)
#    1251     return self.named_transformers_[key]
#    1252 except AttributeError as e:
# -> 1253     raise TypeError(
#    1254         "ColumnTransformer is subscriptable after it is fitted"
#    1255     ) from e
#    1256 except KeyError as e:
#    1257     raise KeyError(f"'{key}' is not a valid transformer name") from e
#
# TypeError: ColumnTransformer is subscriptable after it is fitted

# %%
preprocessor = pipe.named_steps["preprocessor"]
preprocessor
# Out:
# ColumnTransformer(transformers=[('Preprocessing numerical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', MinMaxScaler())]),
#                                  ['Age', 'Fare']),
#                                 ('Preprocessing categorical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot', OneHotEncoder())]),
#                                  ['Embarked', 'Sex'])])

# %%
preprocessor._transformers
# Out:
# [('Preprocessing numerical',
#   Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                   ('scaler', MinMaxScaler())])),
#  ('Preprocessing categorical',
#   Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                   ('onehot', OneHotEncoder())]))]

# %%
preprocessor.named_transformers_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 preprocessor.named_transformers_
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:598, in ColumnTransformer.named_transformers_(self)
#     591 """Access the fitted transformer by name.
#     592
#     593 Read-only attribute to access any transformer by given name.
#     594 Keys are transformer names and values are the fitted transformer
#     595 objects.
#     596 """
#     597 # Use Bunch object to improve autocomplete
# --> 598 return Bunch(**{name: trans for name, trans, _ in self.transformers_})
#
# AttributeError: 'ColumnTransformer' object has no attribute 'transformers_'

# %%
preprocessor.named_transformers_["Preprocessing numerical"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 preprocessor.named_transformers_["Preprocessing numerical"]
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:598, in ColumnTransformer.named_transformers_(self)
#     591 """Access the fitted transformer by name.
#     592
#     593 Read-only attribute to access any transformer by given name.
#     594 Keys are transformer names and values are the fitted transformer
#     595 objects.
#     596 """
#     597 # Use Bunch object to improve autocomplete
# --> 598 return Bunch(**{name: trans for name, trans, _ in self.transformers_})
#
# AttributeError: 'ColumnTransformer' object has no attribute 'transformers_'

# %%
import numpy as np

new_data = {
    "Age": [22, np.nan, 35, 28, np.nan],
    "Fare": [7.25, 8.05, np.nan, 13.00, 15.50]
}

new_data = pd.DataFrame(new_data)

# %%
pipe['preprocessor']['Preprocessing numerical']
# Out:
# ColumnTransformer(transformers=[('Preprocessing numerical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', MinMaxScaler())]),
#                                  ['Age', 'Fare']),
#                                 ('Preprocessing categorical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot', OneHotEncoder())]),
#                                  ['Embarked', 'Sex'])])

# %%
numeric_preprocessor = preprocessor.named_transformers_["Preprocessing numerical"]

# Appliquer la transformation aux nouvelles données (uniquement les colonnes numériques)
new_data_transformed = numeric_preprocessor.transform(new_data[numeric_features])

# Convertir en DataFrame avec les noms des colonnes d'origine
new_data_transformed = pd.DataFrame(new_data_transformed, columns=numeric_features)

print(new_data_transformed)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 numeric_preprocessor = preprocessor.named_transformers_["Preprocessing numerical"]
#       3 # Appliquer la transformation aux nouvelles données (uniquement les colonnes numériques)
#       4 new_data_transformed = numeric_preprocessor.transform(new_data[numeric_features])
#
# File /opt/conda/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:598, in ColumnTransformer.named_transformers_(self)
#     591 """Access the fitted transformer by name.
#     592
#     593 Read-only attribute to access any transformer by given name.
#     594 Keys are transformer names and values are the fitted transformer
#     595 objects.
#     596 """
#     597 # Use Bunch object to improve autocomplete
# --> 598 return Bunch(**{name: trans for name, trans, _ in self.transformers_})
#
# AttributeError: 'ColumnTransformer' object has no attribute 'transformers_'
